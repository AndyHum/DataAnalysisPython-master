# %%
import pandas as pd
import os
from glob import glob
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_PATH = 'C:/Users/Andy/Documents/guo_pengcheng_001643483/Python4DataAnalysis/DataAnalysisPython/final _project/Analysis'

# %%
data1 = pd.read_csv(DATA_PATH + '/Analysis2/Average_Earning.csv')
del data1['Unnamed: 0']
data1
# Out:
#    Year       Avg
# 0  2012  62207.34
# 1  2013  61611.57
# 2  2014  66920.91
# 3  2015  70856.19

# %%
g = sns.regplot(x="Year", y="Avg", data=data1)
plt.savefig("output1.png")

# %%
data2 = pd.read_csv(DATA_PATH + '/Analysis3/Average_Incident.csv')
del data2['Unnamed: 0']
data2
# Out:
#    Year  Number Of Incident
# 0  2012               43186
# 1  2013               87052
# 2  2014               88058
# 3  2015               49760

# %%
g = sns.regplot(x="Year", y="Number Of Incident", data=data2)
plt.savefig("output2.png")
